# %%
#load needed libraries
import urllib.request
from bs4 import BeautifulSoup
import re
import pandas as pd

# Create query variables
# base url string of site
urlBase = "https://edh-www.adw.uni-heidelberg.de"
# query parameters for the url, page size set to 100
urlQueryBase = "/inschrift/erweiterteSuche?hd_nr=&tm_nr=&beleg=c&land=&fo_antik=&fo_modern=&fundstelle=&region=&compFundjahr=eq&fundjahr=&aufbewahrung=&inschriftgattung=&sprache=L&inschrifttraeger=&compHoehe=eq&hoehe=&compBreite=eq&breite=&compTiefe=eq&tiefe=&bh=&palSchreibtechnik=&dat_tag=&dat_monat=&dat_jahr_a=&dat_jahr_e=&hist_periode=&religion=&literatur=&kommentar=&p_name=&p_praenomen=&p_nomen=&p_cognomen=&p_supernomen=&p_tribus=&p_origo=&p_geschlecht=&p_status=&compJahre=eq&p_lJahre=&compMonate=eq&p_lMonate=&compTage=eq&p_lTage=&compStunden=eq&p_lStunden=&atext1=&bool=AND&atext2=&beleg89=ja&nurMitFoto=ja&sort=hd_nr&anzahl=100&addFeldMaterial=ja&addFeldDTyp=ja&addFeldIGat=ja&start="
# offset of the query
offset = 0
# parameter to specify language as english
paramLang = "&lang=en"

#create query
url = urlBase + urlQueryBase + str(offset)
print(url)
# Out:
# https://edh-www.adw.uni-heidelberg.de/inschrift/erweiterteSuche?hd_nr=&tm_nr=&beleg=c&land=&fo_antik=&fo_modern=&fundstelle=&region=&compFundjahr=eq&fundjahr=&aufbewahrung=&inschriftgattung=&sprache=L&inschrifttraeger=&compHoehe=eq&hoehe=&compBreite=eq&breite=&compTiefe=eq&tiefe=&bh=&palSchreibtechnik=&dat_tag=&dat_monat=&dat_jahr_a=&dat_jahr_e=&hist_periode=&religion=&literatur=&kommentar=&p_name=&p_praenomen=&p_nomen=&p_cognomen=&p_supernomen=&p_tribus=&p_origo=&p_geschlecht=&p_status=&compJahre=eq&p_lJahre=&compMonate=eq&p_lMonate=&compTage=eq&p_lTage=&compStunden=eq&p_lStunden=&atext1=&bool=AND&atext2=&beleg89=ja&nurMitFoto=ja&sort=hd_nr&anzahl=100&addFeldMaterial=ja&addFeldDTyp=ja&addFeldIGat=ja&start=0

# %%
#1. Load query results page
f = urllib.request.urlopen(url)
htmlDocString = f.read() 
f.close()
# take a quick look at the html
print(htmlDocString)
# Out:
# b'<!DOCTYPE html>\n<html>\n<head>\n<meta charset="utf-8">\n<meta name="viewport" content="width=device-width, initial-scale=1.0">\n<meta name="keywords" content="latin epigraphy,epigraphy,inscription,database,ancient,Rome,Roman Empire,fotos,images,bibliography" />\n<meta name="description" content="The Epigraphic Database Heidelberg contains the texts of Latin and bilingual (i.e. Latin-Greek) inscriptions of the Roman Empire." />\n<meta name="publisher" content="Heidelberg Academy of Sciences and Humanities" />\n<meta name="author" content="Frank Grieshaber" />\n\n<title>Inscriptions: Advanced Search - Epigraphic Database Heidelberg</title>\n<link rel="stylesheet" href="/edh-css/jquery-ui-slider-pips.css" />\n<link rel="stylesheet" href="/edh-css/jquery.tree.css" />\n<link rel="stylesheet" href="/edh-css/jq/jquery-ui.css" />\n<link rel="stylesheet" href="https://code.jquery.com/ui/1.10.1/themes/base/jquery-ui.css" />\n<link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/leaflet/0.7.7/leaflet.css" />\n<link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.3.0/MarkerCluster.css" />\n<link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.3.0/MarkerCluster.Default.css" />\n<link rel="stylesheet" href="/edh-css/edh2.1.css" />\n<script src="https://code.jquery.com/jquery-1.7.1.min.js"></script>\n<script src="https://code.jquery.com/ui/1.8.16/jquery-ui.min.js"></script>\n</head>\n<body>\n<table id="tabelleCont" width="100%">\n<!-- Kopf Anfang -->\n<tr id="kopfHoehe" >\n  <td colspan="3">\n    <table width="100%">\n    <tr>\n      <td id="col1" rowspan="2">&nbsp;</td>\n      <td id="col2_oben"><a href="http://www.haw.uni-heidelberg.de/index.en.html">HEIDELBERG ACADEMY OF SCIENCES AND HUMANITIES</a></td>\n      <td id="col3" rowspan="2">&nbsp;</td>\n    </tr>\n    <tr>\n      <td id="col2_unten">\n        <img src="/images/edh_en.png" alt="Epigraphic Database Heidelberg" style="width:584px;height:37px" >\n      </td>\n    </tr>\n    </table>\n    <table width="100%">\n    <tr>\n      <td id="subHeaderLinks">&nbsp;</td>\n      <td id="subHeaderMitte">&nbsp;</td>\n      <td id="subHeaderRechts">&nbsp;</td>\n    </tr>\n    </table>\n<!-- Navigation Anfang -->\n    <table width="100%">\n    <tr>\n      <td id="naviHome"><a href="/home">Home</a></td>\n      <td class="naviHell">\n        <ul class="jsddm2">\n        <li><a href="">Project</a>\n          <ul>\n            <li><a href="/projekt/konzept">Concept</a></li>\n            <li><a href="/projekt/geschichte">History</a></li>\n            <li><a href="/projekt/kooperationen">Cooperations</a></li>\n            <li><a href="/projekt/mitarbeiter">Research Team Members</a></li>\n            <li><a href="/projekt/veranstaltungen">Events and Presentations</a></li>\n          </ul>\n        </li>\n        </ul>\n      </td>\n       <td class="naviDunkel">\n         <table style="text-align:center;margin-left:auto;margin-right:auto">\n           <tr>\n             <td>\n              <ul id="jsddm">\n              <li><a href="/inschrift/suche">Inscriptions</a>\n                <ul>\n                <li><a href="/inschrift/suche">Simple Search</a></li>\n                <li><a href="/inschrift/erweiterteSuche">Advanced Search</a></li>\n                <li><a href="/inschrift/browse">Browse...</a></li>\n                </ul>\n              </li>\n              <li><a href="/foto/suche">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Photos</a></li>\n              <li><a href="/bibliographie/suche">Bibliography</a></li>\n              <li><a href="/data">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Data</a></li>\n              </ul>\n             </td>\n           </tr>\n         </table>\n       </td>\n      <td class="naviHellrechts">\n        <ul class="jsddm2">\n          <li><a href="/links">Links</a></li>\n        </ul>\n      </td>\n      <td id="naviFlaggen1">&nbsp;</td>\n      <td id="naviFlaggen2" onMouseOver=\'th ...

# %%
#2. Find a single result

#    - Create BeautifulSoup from result string
htmlSoup = BeautifulSoup(htmlDocString,'html.parser')
#print(htmlSoup.prettify())

#    - Get a list of all results reffer 'table' elements of class 'treffertabelle'
tableRefferList = htmlSoup.select('table.treffertabelle')
#print(type(tableRefferList)) #<class 'list'>
#print(len(tableRefferList))  #100

#    - Load a single result into a variable
#set curTable to 3rd table scrap info for a single result while developing
#later this will just be a loop variable
curTable = tableRefferList[2]
print (curTable.prettify())
# Out:
# <table class="treffertabelle">
#  <thead>
#   <tr>
#    <th colspan="3" id="zwischenueberschrift">
#     Number 3:
#     <a class="linkLastUpdateDetail" href="/edh/inschrift/HD000042">
#      <span style="background-color: #FFFF00">
#      </span>
#      <span style="background-color: #FFFF00">
#      </span>
#      <span style="background-color: #FFFF00">
#      </span>
#      <span style="background-color: #FFFF00">
#      </span>
#      <span style="background-color: #FFFF00">
#      </span>
#      <span style="background-color: #FFFF00">
#      </span>
#      HD000042  – open detailed view...
#     </a>
#     <span style="font-weight:normal">
#      (newer version at:
#      <a href="http://www.edr-edr.it/edr_programmi/res_complex_comune.php?Bibliografia[]=HD000042" target="_blank">
#       EDR
#      </a>
#      )
#     </span>
#    </th>
#   </tr>
#  </thead>
#  <tbody>
#   <tr>
#    <td width="200px">
#     <a href="/edh/geographie/19001" style="background-image: none;color:#1F6B3B;padding:0;">
#      <div id="map_canvas3" style="width:200px;height:200px; border: 1px solid #ccc">
#      </div>
#     </a>
#    </td>
#    <script type="text/javascript">
#     $(document).ready(function(){
#         var pelagiosMap = L.tileLayer('https://dare.ht.lu.se/tiles/imperium/{z}/{x}/{y}.png',{attribution: 'Data: <a href="http://dare.ht.lu.se">DARE</a>'});
#             var map = L.map('map_canvas3', {
#                 center: [41.895466,12.482324],
#                 zoom: 4,
#                 zoomControl:false,
#                 layers: [pelagiosMap]
#             });
#             map.dragging.disable();
#             map.touchZoom.disable();
#             map.doubleClickZoom.disable();
#             map.scrollWheelZoom.disable();
#             map.keyboard.disable();
#             var marker3 = L.marker([41.895466,12.482324]).addTo(map);
#     });
#    </script>
#    <td>
#     <table class="innerTable">
#      <tr>
#       <td style="text-align:right;width:120px">
#        <b>
#         Transcription:
#        </b>
#       </td>
#       <td>
#        Maecia / M(arci) l(iberta) Haline / fecit sibe(!) / [s]uisque / [O]vioque / [So?]dali / [in fr(onte) p(edes)] XIIII / [in ag(ro) p(edes) ---]
#       </td>
#      </tr>
#      <tr>
#       <td align="right">
#        <b>
#         Find spot:
#        </b>
#       </td>
#       <td>
#        <a href="/edh/geographie/19001" style="background-image: url(/images/pfeil_transparent.png);background-position: left center;color: #1F6B3B;padding-left: 16px;background-repeat: no-repeat;">
#         Roma (Roma)
#        </a>
#       </td>
#      </tr>
#      <tr>
#       <td align="right">
#        <b>
#         Italic region:
#        </b>
#       </td>
#       <td>
#        <a href="/edh/geographie/900060" style="background-image: url(/images/pfeil_transparent.png);background-position: left center;color: #1F6B3B;padding-left: 16px;background-repeat: no-repeat;">
#         Roma
#        </a>
#        (Italy)
#       </td>
#      </tr>
#      <tr>
#       <td align="right">
#        <b>
#         Chronological data:
#        </b>
#       </td>
#       <td>
#        70 BC – 31 BC
#       </td>
#      </tr>
#      <tr>
#       <td align="right">
#        <b>
#         Literature
#         <a class="help" href="#" onclick="showDialog('/tplInhalt/textSucheLiteratur_en.html','Literature','500px'); return false;">
#          <img alt="Hilfe" src="/images/hilfe_14.png"/>
#         </a>
#         :
#        </b>
#       </td>
#       <td>
#        AE 1983, 0036.
#        <a class="tt">
#         (B)
#         <span class="tooltip">
#          abweichende Lesung, s. Kommentar
#         </span>
#        </a>
#        <br/>
#        G. Pisani Sartorio, in: G. Barbieri (Hrsg.), Il lapidario Zeri di Mentana (Roma 1982) 6-7, Nr. 5; tav. 4.
#        <a class="tt">
#         (B)
#         <span class="tooltip">
#          abweichende Lesung, s. Kommentar
#         </span>
#        </a>
#        - AE 1983.
#        <br/>
#       </td>
#      </tr>
#      <tr>
#       <td align="right">
#        <b>
#         type of inscription:
#        </b>
#       </td>
#       <td>
#        epitaph
#       </td>
#      </tr>
#      <tr>
#       <td align="right">
#        <b>
#         type of monument:
#        </b>
#       </td>
#       <td>
#        stele
#       </td>
#      </tr>
#      <tr>
#       <td align="right">
#        <b>
#         material:
#        </b>
#       </td>
#       <td>
#        travertine: rocks - chemische Sedimente
#       </td>
#      </tr>
#     </table>
#    </td>
#    <td align="center" style="min-width: 250px; max-width: 250px; width: 250px;">
#     <a href="/edh/inschrift/HD000042/iiif" style="background-image: none; color:#1F6B3B;">
#      <img src="/fotos/F023476.JPG" style="max-height:200px;max-width:200px;border:0px solid #000;"/>
#     </a>
#    </td>
#   </tr>
#  </tbody>
# </table>

# %%
#3. Find the link to the detailed page
#    - Find link element to more detailed page class 'linkLastUpdateDetail'
detailLinks = curTable.select('a.linkLastUpdateDetail')
#print(detailLinks)

#    - Load href property into a variable
urlDetail = None #set to none for no detaillinks case
for link in detailLinks:
    urlDetail = urlBase + link.get('href') + paramLang
    break
print(urlDetail)
# Out:
# https://edh-www.adw.uni-heidelberg.de/edh/inschrift/HD000042&lang=en

# %%
#questo è quello che ha usato lui per trovare "material" e funziona ma per caso
for td in curTable.select("table.innerTable tr td"):
    if (td.text == 'language:'):
        print(td.text)
        tdn = td.fetchNextSiblings()
        print(tdn[0].text)
# Out:
# material:
# travertine: rocks - chemische Sedimente

# %%
######################################################
## code to debug the "access denied" issue
######################################################
import requests
# inspect website to find particular item code
url = 'https://edh-www.adw.uni-heidelberg.de/edh/inschrift/HD000042&lang=en'

badresponse = requests.get(url) #access the website with requests library
print (badresponse.text)
print(badresponse.status_code)
print ("-------------")

# spoofing user agent
user_agent = 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_3) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/35.0.1916.47 Safari/537.36'
goodresponse = requests.get(url, headers={"User-agent":user_agent}) #access the website with requests library
print(goodresponse.status_code)

######################################################
## Code to understand what's bad with the html 
######################################################

from bs4 import BeautifulSoup
import requests

# inspect website to find particular item code
url = 'https://edh-www.adw.uni-heidelberg.de/edh/inschrift/HD000042&lang=en'

user_agent = 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_3) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/35.0.1916.47 Safari/537.36'
response = requests.get(url, headers={"User-agent":user_agent}) #access the website with requests library

#parse HTML and save to BeautifulSoup object
bigsoup = BeautifulSoup(response.text, "html.parser")
## the html parser give a wrong html (check for</body></html> in wrong position)
print ("--------------------------------------start------------------------------------")
print(bigsoup)
print ("--------------------------------------end------------------------------------")


######################################################
## the solution
######################################################

from bs4 import BeautifulSoup
import requests

# inspect website to find particular item code
url = 'https://edh-www.adw.uni-heidelberg.de/edh/inschrift/HD000042&lang=en'

user_agent = 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_3) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/35.0.1916.47 Safari/537.36'
response = requests.get(url, headers={"User-agent":user_agent}) #access the website with requests library

#parse HTML and save to BeautifulSoup object
bigsoup = BeautifulSoup(response.text, "html.parser")

# no matter in what table, looking for <td>language</td> --> orginal is <td><b>language</b></td>
thelanguage = bigsoup.find('td', text='language').find_next('td')
print(thelanguage.text)
# Out:
# Access denied.
# 403
# -------------
# 200
# --------------------------------------start------------------------------------
# <!DOCTYPE html>
#
# <html>
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <meta content="latin epigraphy,epigraphy,inscription,database,ancient,Rome,Roman Empire,fotos,images,bibliography" name="keywords">
# <meta content="The Epigraphic Database Heidelberg contains the texts of Latin and bilingual (i.e. Latin-Greek) inscriptions of the Roman Empire." name="description">
# <meta content="Heidelberg Academy of Sciences and Humanities" name="publisher"/>
# <meta content="Frank Grieshaber" name="author"/>
# <title>Epigraphic Database Heidelberg</title>
# <link href="/edh-css/jquery-ui-slider-pips.css" rel="stylesheet"/>
# <link href="/edh-css/jquery.tree.css" rel="stylesheet"/>
# <link href="/edh-css/jq/jquery-ui.css" rel="stylesheet"/>
# <link href="https://code.jquery.com/ui/1.10.1/themes/base/jquery-ui.css" rel="stylesheet"/>
# <link href="https://cdnjs.cloudflare.com/ajax/libs/leaflet/0.7.7/leaflet.css" rel="stylesheet"/>
# <link href="https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.3.0/MarkerCluster.css" rel="stylesheet"/>
# <link href="https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.3.0/MarkerCluster.Default.css" rel="stylesheet"/>
# <link href="/edh-css/edh2.1.css" rel="stylesheet"/>
# <script src="https://code.jquery.com/jquery-1.7.1.min.js"></script>
# <script src="https://code.jquery.com/ui/1.8.16/jquery-ui.min.js"></script>
# </meta></meta></head>
# <body>
# <table id="tabelleCont" width="100%">
# <!-- Kopf Anfang -->
# <tr id="kopfHoehe">
# <td colspan="3">
# <table width="100%">
# <tr>
# <td id="col1" rowspan="2"> </td>
# <td id="col2_oben"><a href="http://www.haw.uni-heidelberg.de/index.en.html">HEIDELBERG ACADEMY OF SCIENCES AND HUMANITIES</a></td>
# <td id="col3" rowspan="2"> </td>
# </tr>
# <tr>
# <td id="col2_unten">
# <img alt="Epigraphic Database Heidelberg" src="/images/edh_en.png" style="width:584px;height:37px"/>
# </td>
# </tr>
# </table>
# <table width="100%">
# <tr>
# <td id="subHeaderLinks"> </td>
# <td id="subHeaderMitte"> </td>
# <td id="subHeaderRechts"> </td>
# </tr>
# </table>
# <!-- Navigation Anfang -->
# <table width="100%">
# <tr>
# <td id="naviHome"><a href="/home">Home</a></td>
# <td class="naviHell">
# <ul class="jsddm2">
# <li><a href="">Project</a>
# <ul>
# <li><a href="/projekt/konzept">Concept</a></li>
# <li><a href="/projekt/geschichte">History</a></li>
# <li><a href="/projekt/kooperationen">Cooperations</a></li>
# <li><a href="/projekt/mitarbeiter">Research Team Members</a></li>
# <li><a href="/projekt/veranstaltungen">Events and Presentations</a></li>
# </ul>
# </li>
# </ul>
# </td>
# <td class="naviDunkel">
# <table style="text-align:center;margin-left:auto;margin-right:auto">
# <tr>
# <td>
# <ul id="jsddm">
# <li><a href="/inschrift/suche">Inscriptions</a>
# <ul>
# <li><a href="/inschrift/suche">Simple Search</a></li>
# <li><a href="/inschrift/erweiterteSuche">Advanced Search</a></li>
# <li><a href="/inschrift/browse">Browse...</a></li>
# </ul>
# </li>
# <li><a href="/foto/suche">       Photos</a></li>
# <li><a href="/bibliographie/suche">Bibliography</a></li>
# <li><a href="/data">      Data</a></li>
# </ul>
# </td>
# </tr>
# </table>
# </td>
# <td class="naviHellrechts">
# <ul class="jsddm2">
# <li><a href="/links">Links</a></li>
# </ul>
# </td>
# <td id="naviFlaggen1"> </td>
# <td id="naviFlaggen2" onclick="window.open('/edh/inschrift/HD000042&amp;lang=de','_self')" onmouseover='this.style.cursor="pointer"'> </td>
# <td id="naviFlaggen3"> </td>
# <td id="naviFlaggen4" onclick="window.open('/edh/inschrift/HD000042&amp;lang=en','_self')" onmouseover='this.style.cursor="pointer"'> </td>
# <td id="naviFlaggen5"> </td>
# </tr>
# </table>
# <!-- Navigation Ende -->
# <table width="100%">
# <tr>
# <td id="naviSchattenLinks"> </td>
# <td id="naviSchattenMitte"> </td>
# <td id="naviSchattenRechts"> </td>
# </tr>
# </table>
# </td>
# </tr>
# <!-- Kopf Ende -->
# <tr>
# <td id="inhaltLinks">
# <div id="hideAll" style="display: none"></div>
# <div id="spinner" style="display: none"></div>
# <!-- Infobloecke Anfang -->
# <table class="infoBlockTabelleHome" style="margin-top:100px;background-image:url('/images/infoblockLinks.png');" width="100%">
# <tr>
# <td colspan="2"><br/><span style="color:#323586;font-size:90%;padding:1px;">HD-Nr.:</span>
# <form action="" onsubmit="this.action=changeURL();">
# <input id="getHDNr" size="8" type="text"/>
# </form>
# </td>
# </tr>
# <tr>
# <td colspan="2" style="padding-bottom:20px"><br/><span style="color:#323586;font-size:90%;padding:1px;">Quick Search Inscriptions-Db<a class="help" href="#" onclick="showDialog('/tplInhalt/schnellsuche_de.html','Quick Search Inscriptions','500px'); return false;"> <img alt="Hilfe" src="/images/hilfe_14.png"/></a> </span>
# <form action="/inschrift/suche?" method="get">
# <input name="qs" size="8" style="margin-top:4px" type="text"/>
# </form>
# </td>
# </tr>
# <tr><td colspan="2" style="padding:0px;height:5px;background-image:url(/images/seitenleiste_links_schatten.png)"> </td></tr>
# </table>
# <table class="infoBlockTabelleHome" style="margin-top:40px;background-image:url('/images/infoblockLinks.png');" width="100%">
# <tr>
# <td style="width:12px;padding-top:20px;"><a href="/inschrift/suche"><img alt="pfeil" src="/images/pfeil_blau.png" style="padding-top:2px;width:6px;height:11px"/></a></td><td style="padding-top:20px;padding-left:0px"><a href="/inschrift/suche">
# 80152</a></td></tr><tr><td colspan="2"><a href="/inschrift/suche">Inscriptions    </a></td>
# </tr>
# <tr>
# <td style="width:12px;padding-top:20px;"><a href="/fotos/suche"><img alt="pfeil" src="/images/pfeil_blau.png" style="padding-top:3px;width:6px;height:11px"/></a></td><td style="padding-left:0px;padding-top:20px;"><a href="/foto/suche">
# 38919</a></td></tr><tr><td colspan="2"><a href="/foto/suche">Photos        </a></td>
# </tr>
# <tr>
# <td style="width:12px;padding-top:20px;"><a href="/bibliographie/suche"><img alt="pfeil" src="/images/pfeil_blau.png" style="padding-top:3px;width:6px;height:11px"/></a></td><td style="padding-left:0px;padding-top:20px;"><a href="/bibliographie/suche">
# 16398</a></td></tr><tr><td colspan="2"><a href="/bibliographie/suche">Publications        </a></td>
# </tr>
# <tr>
# <td style="width:12px;padding-top:20px;"><a href="/bibliographie/suche"><img alt="pfeil" src="/images/pfeil_blau.png" style="padding-top:3px;width:6px;height:11px"/></a></td><td style="padding-left:0px;padding-top:20px;"><a href="#">
# 29953</a></td></tr><tr><td colspan="2" style="padding-bottom:20px"><a href="#">Findspots        </a></td>
# </tr>
# <tr><td colspan="2" style="padding:0px;height:21px;background-image:url(/images/seitenleiste_links_schatten.png)"> </td></tr>
# </table>
# <!-- Infobloecke Ende -->
# </td>
# <!-- eigentlicher Inhalt Anfang -->
# <td id="inhaltMitte">
# <div style="padding-left:12px;text-align:center;color:#f00;font-weight:bold;"></div>
# <div class="subNavi"><h3>Epigraphic Text Database: Detailed View</h3></div><table style="width:90%;margin:auto auto 2em;margin-bottom:0px;font-size:1em;border:1 solid #00f;padding-bottom: 12px;"><tr><td align="right"><a href="#" id="feedbackDialog"><img src="/images/mail-icon.png" style="vertical-align:top;" title="Feedback"/></a>   <a href="/edh/inschrift/HD000042.xml"><img src="/images/epidoc-icon.png" style="padding-bottom: 12px;" title="Epidoc XML"/></a>   <a href="/edh/inschrift/HD000042.json"><img src="/images/json-icon.png" style="padding-bottom: 12px;" title="JSON"/></a>   <a href="/edh/inschrift/HD000042.ttl"><img src="/images/rdf-icon.png" style="padding-bottom: 12px;" title="RDF/Turtle"/></a>   <a href="/edh/inschrift/HD000042/druckansicht"><img src="/images/printer-icon.png" style="padding-bottom: 12px;" title="Druckansicht"/></a></td></tr></table> <script type="text/javascript">
#         isFeedbackSent = false;
#         $(document).ready(function() {
#             $('#feedbackDialog').click(function() {
#                 if (isFeedbackSent){
#                   $('#fb_name').val('');
#                   $('#fb_email').val('');
#                   $('#fb_feedback_text').val('');
#                   $('#fb_success').remove();
#                   isFeedbackSent = false;
#                 }
#                 $( "#feedback" ).dialog( "open" );
#                 $('#feedback').dialog({
#                     width:550
#                 });
#                 return false;
#             });
#             $('#sendFeedback').click(function() {
#                 if (! isFeedbackSent && $('#fb_name').val() != "" && $('#fb_email').val() != "" && $('#fb_feedback_text').val() != ""){
#                 $.post("/m/sendMessage.php",
#                 {
#                     name: $('#fb_name').val(),
#                     email: $('#fb_email').val(),
#                     hd_nr: "HD000042",
#                     feedback: $('#fb_feedback_text').val()
#                 },
#                 function(data, status){
#                     if (! isFeedbackSent){
#                       $('#feedback').append("<p id='fb_success' align=center><b>Thank you for your feedback!</b></p>");
#                       isFeedbackSent = true;
#                     }
#                 });
#                 return false;
#                 }
#             });
#         });
#         </script>
# <div id="feedback" style="display:none" title="Feedback: HD000042"><form>
# <table id="feedback_table" style="border:none;width:100%">
# <tr><td align="right" width="20%"><b>Name</b>:</td><td><input id="fb_name" required="" style="width:90%" type="text"/></td></tr>
# <tr><td align="right"><b>Email</b>:</td><td><input id="fb_email" required="" style="width:90%" type="email"/></td></tr>
# <tr><td align="right"><b>Feedback</b>:</td><td><textarea id="fb_feedback_text" required="" rows="10" style="width:90%"></textarea></td></tr>
# <tr><td></td><td><input id="sendFeedback" type="submit" value="send feedback"/></td></tr>
# </table>
# </form></div>
# <script src="https://cdnjs.cloudflare.com/ajax/libs/leaflet/0.7.7/leaflet.js" type="text/javascript"></script><table class="treffertabelle">
# <tr><td colspan="3" id="zwischenueberschrift"><b>Canonical URI<b>: <span id="copy_edh_uri" style="font-family: 'Myriad Pro',Helvetica,Arial,Verdana,sans-serif;font-size:1em;font-weight:normal">https://edh-www.adw.uni-heidelberg.de/edh/inschrift/HD000042 (last update: 4 January 2010, Feraudi)</span> <img alt="copy to clipboard" class="btn" data-clipboard-text="https://edh-www.adw.uni-heidelberg.de/edh/inschrift/HD000042 (last update: 4 January 2010, Feraudi)" id="copy-button" src="/images/clippy.png" style="margin-left:10px" title="copy canonical URI to clipboard"/><span id="copy_result" style="margin-left:0.5em;color:#006837"></span></b></b></td></tr><tr><td width="150px"><a href="/edh/geographie/19001" style="background-image: none;color:#1F6B3B;padding:0;"><div id="map_canvas" style="width:200px;height:200px; border: 1px solid #ccc"></div></a></td>
# <script type="text/javascript">
#     $(document).ready(function(){
#         var pelagiosMap = L.tileLayer('https://dare.ht.lu.se/tiles/imperium/{z}/{x}/{y}.png',{attribution: 'Data: <a href="http://dare.ht.lu.se">DARE</a>'});
#             var map = L.map('map_canvas', {
#                 center: [41.895466,12.482324],
#                 zoom: 4,
#                 zoomControl:false,
#                 layers: [pelagiosMap]
#             });
#             map.dragging.disable();
#             map.touchZoom.disable();
#             map.doubleClickZoom.disable();
#             map.scrollWheelZoom.disable();
#             map.keyboard.disable();
#             var marker = L.marker([41.895466,12.482324]).addTo(map);
#     });
#     </script>
# <td><table class="innerTable"><tr><td style="text-align:right;width:120px"><b>Transcription:</b></td><td>Maecia / M(arci) l(iberta) Haline / fecit sibe(!) / [s]uisque / [O]vioque / [So?]dali / [in fr(onte) p(edes)] XIIII / [in ag(ro) p(edes) ---]</td></tr><tr valign="top"><td align="right"><b>Majuscule:</b></td><td> MAECIA <br/> M L HALINE <br/> FECIT SIBE <br/> [ ]VISQVE <br/> [ ]VIOQVE <br/> [ ]DALI <br/> [ ] XIIII <br/> [ ]</td></tr><tr><td align="right"><b>Chronological data:</b></td><td>70 BC – 31 BC</td></tr><tr><td align="right"><b>Literature <a class="help" href="#" onclick="showDialog('/tplInhalt/textSucheLiteratur_en.html','Literature','500px'); return false;"><img alt="Hilfe" src="/images/hilfe_14.png"/></a>:</b></td><td>AE 1983, 0036. <a class="tt">(B)<span class="tooltip">abweichende Lesung, s. Kommentar</span></a> <br/> G. Pisani Sartorio, in: G. Barbieri (Hrsg.), Il lapidario Zeri di Mentana (Roma 1982) 6-7, Nr. 5; tav. 4. <a class="tt">(B)<span class="tooltip">abweichende Lesung, s. Kommentar</span></a> - AE 1983. <br/> </td></tr></table></td><td align="center" rowspan="100" width="230px"><a href="/edh/inschrift/HD000042/iiif#?cv=0&amp;locale=en-GB" id="&lt;a style='color:#fff;font-weight:bold;' href='/edh/foto/F023476'&gt;F023476 (detailed view)&lt;/a&gt;      &lt;a style='color:#fff;font-weight:bold;' href='/edh/foto/ausdrucken?link=F023476.JPG'&gt;print foto&lt;/a&gt;" style="background-image: none; color:#1F6B3B;"><img src="/fotos/F023476.JPG" style="max-width:200px;max-height:200px;margin:10px;padding:10px;border:1px solid #fff"/></a></td></tr><tr><td colspan="2" id="zwischenueberschrift"><b>Find circumstances / present location<b></b></b></td></tr><tr valign="top"><td><b>Italic region</b></td><td><a href="/edh/geographie/900060">Roma</a></td></tr>
# </table></td></tr>
# <tr valign="top"><td><b>modern country</b></td><td> Italy</td></tr>
# </table></body></html>
# <tr valign="top"><td width="150px"><b>ancient find spot</b></td><td> Roma</td></tr>
# <tr valign="top"><td width="150px"><b>modern find spot</b></td><td><a href="/edh/geographie/19001">Roma</a>    (<a href="/inschrift/umkreissuche/19001/karte">Radial Search</a>)</td></tr>
# <tr valign="top"><td width="150px"><b>find spot (village, street, etc.)</b></td><td> </td></tr>
# <tr><td><b>modern region</b></td><td>Roma</td></tr>
# <tr><td><b>present location</b></td><td>Mentana, Privatbesitz</td></tr>
# <tr><td colspan="2" id="zwischenueberschrift"><b>Type of inscription / language<b></b></b></td></tr><tr><td><b>type of inscription</b></td><td>epitaph</td></tr>
# <tr><td><b>language</b></td><td>Latin</td></tr>
# <tr><td colspan="2" id="zwischenueberschrift"><b>Type of monument<b></b></b></td></tr><tr><td><b>type of monument</b></td><td>stele</td></tr>
# <tr><td><b>material</b></td><td>travertine: rocks - chemische Sedimente</td></tr>
# <tr><td><b>height</b></td><td>(40) cm</td></tr>
# <tr><td><b>width</b></td><td>30 cm</td></tr>
# <tr><td><b>letter size</b></td><td>4-2 cm</td></tr>
# <tr><td colspan="2" id="zwischenueberschrift"><b>Historical relevant data<b></b></b></td></tr><tr><td><b>social / economic / legal history</b></td><td>data available</td></tr><tr><td colspan="2" id="zwischenueberschrift"><b>Commentary</b></td></tr><tr valign="top"><td> </td><td> (B): Pisani Sartorio, AE 1983: Z. 3: [f]ecit; Pisani Sartorio: Z. 5: [s]uoque, [O]vioque wird allerdings nicht ausgeschlossen; AE 1983: Z. 5: [O]vioque Sodali.</td></tr>
# <tr><td colspan="2" id="zwischenueberschrift"><b>Persons</b></td></tr><tr><td style="border:none;border-left:1px solid #fff;border-top: 1px solid #fff"><b>person 1</b></td><td><b>name</b>: Maecia M.l. Haline</td></tr><tr><td style="border:none;border-left:1px solid #fff"></td><td><b>praenomen</b>: </td></tr><tr><td style="border:none;border-left:1px solid #fff"></td><td><b>nomen</b>: Maecia</td></tr><tr><td style="border:none;border-left:1px solid #fff"></td><td><b>cognomen</b>: Haline</td></tr><tr><td style="border:none;border-left:1px solid #fff"></td><td><b>gender</b>: female</td></tr><tr><td style="border:none;border-left:1px solid #fff"></td><td style="padding:0"><table cellpadding="0" cellspacing="0" style="font-size:1.1em;border:none"><tr><td style="border:0"><b>status</b>:</td><td style="border:0">freedmen / freedwomen</td></tr></table></td></tr><tr><td style="border:none;border-left:1px solid #fff;border-top: 1px solid #fff"><b>person 2</b></td><td><b>name</b>: [O]vio [So?]dali</td></tr><tr><td style="border:none;border-left:1px solid #fff"></td><td><b>praenomen</b>: </td></tr><tr><td style="border:none;border-left:1px solid #fff"></td><td><b>nomen</b>: Ovius+</td></tr><tr><td style="border:none;border-left:1px solid #fff"></td><td><b>cognomen</b>: Sodalis+?</td></tr><tr><td style="border:none;border-left:1px solid #fff"></td><td><b>gender</b>: male</td></tr><tr><td colspan="2" id="zwischenueberschrift"><b>General data<b></b></b></td></tr><tr><td><b>HD no.</b></td><td>HD000042</td></tr>
# <tr valign="top"><td><b>EDH Geo-ID</b></td><td><a href="/edh/geographie/19001">19001</a></td></tr>
# <tr valign="top"><td><b>Pleiades ID</b></td><td><a href="http://pleiades.stoa.org/places/423025">423025</a> <script type="text/javascript">
#         $(document).ready(function() {
#             $('#pelagiosDialog').click(function() {
#             $('#pelagios').dialog( "open" );
#             $('#pelagios').dialog({
#                 width:550,
#                 resizable: false,
#                     create: function() {
#                         $(this).css("maxHeight", 400);
#                     }
#             });
#             return false;
#             });
#         });
#         </script>
#  (<a href="#" id="pelagiosDialog">Related content from Pelagios</a>)<div id="pelagios" style="display:none" title="Related content from Pelagios"><p><a href="http://pelagios-project.blogspot.de/p/about-pelagios.html" target="_blank">Pelagios</a> is a network that interlinks online resources, primarily from the ancient world, via geographical informations (<a href="https://peripleo.pelagios.org/about" target="_blank">list of project partners</a>).</p><p><b>Links to information about this place in gazetteers:</b></p><a href="http://sws.geonames.org/3169070">http://sws.geonames.org/3169070</a><br/>     <a href="http://www.wikidata.org/entity/Q220" style="color:#84a6a4">http://www.wikidata.org/entity/Q220</a><br/>     <a href="http://viaf.org/viaf/145348938" style="color:#84a6a4">http://viaf.org/viaf/145348938</a><br/><a href="http://gazetteer.dainst.org/place/2323295">http://gazetteer.dainst.org/place/2323295</a><br/>     <a href="http://arachne.uni-koeln.de/entity/1207427" style="color:#84a6a4">http://arachne.uni-koeln.de/entity/1207427</a><br/>     <a href="http://arachne.uni-koeln.de/entity/1206529" style="color:#84a6a4">http://arachne.uni-koeln.de/entity/1206529</a><br/>     <a href="http://arachne.uni-koeln.de/entity/3322274" style="color:#84a6a4">http://arachne.uni-koeln.de/entity/3322274</a><br/>     <a href="http://arachne.uni-koeln.de/entity/3416154" style="color:#84a6a4">http://arachne.uni-koeln.de/entity/3416154</a><br/>     <a href="http://arachne.uni-koeln.de/entity/1206250" style="color:#84a6a4">http://arachne.uni-koeln.de/entity/1206250</a><br/>     <a href="http://arachne.uni-koeln.de/entity/3320497" style="color:#84a6a4">http://arachne.uni-koeln.de/entity/3320497</a><br/>     <a href="http://pleiades.stoa.org/places/423025" style="color:#84a6a4">http://pleiades.stoa.org/places/423025</a><br/>     <a href="http://arachne.uni-koeln.de/entity/3524492" style="color:#84a6a4">http://arachne.uni-koeln.de/entity/3524492</a><br/>     <a href="http://arachne.uni-koeln.de/entity/1206008" style="color:#84a6a4">http://arachne.uni-koeln.de/entity/1206008</a><br/>     <a href="http://sws.geonames.org/3169070" style="color:#84a6a4">http://sws.geonames.org/3169070</a><br/>     <a href="http://d-nb.info/gnd/4050471-2" style="color:#84a6a4">http://d-nb.info/gnd/4050471-2</a><br/><a href="http://dare.ht.lu.se/places/1438">http://dare.ht.lu.se/places/1438</a><br/>     <a href="http://sws.geonames.org/3169070" style="color:#84a6a4">http://sws.geonames.org/3169070</a><br/>     <a href="http://www.wikidata.org/entity/Q1747689" style="color:#84a6a4">http://www.wikidata.org/entity/Q1747689</a><br/>     <a href="http://www.wikidata.org/entity/Q220" style="color:#84a6a4">http://www.wikidata.org/entity/Q220</a><br/>     <a href="http://pleiades.stoa.org/places/423025" style="color:#84a6a4">http://pleiades.stoa.org/places/423025</a><br/>     <a href="http://www.trismegistos.org/place/2058" style="color:#84a6a4">http://www.trismegistos.org/place/2058</a><br/><a href="http://vici.org/vici/1692">http://vici.org/vici/1692</a><br/>     <a href="http://pleiades.stoa.org/places/423025" style="color:#84a6a4">http://pleiades.stoa.org/places/423025</a><br/>     <a href="http://www.livius.org/place/rome/rome-photos" style="color:#84a6a4">http://www.livius.org/place/rome/rome-photos</a><br/><a href="http://nomisma.org/id/rome">http://nomisma.org/id/rome</a><br/>     <a href="http://pleiades.stoa.org/places/423025" style="color:#84a6a4">http://pleiades.stoa.org/places/423025</a><br/><a href="http://syriaca.org/place/641">http://syriaca.org/place/641</a><br/>     <a href="http://pleiades.stoa.org/places/423025" style="color:#84a6a4">http://pleiades.stoa.org/places/423025</a><br/>     <a href="http://en.wikipedia.org/wiki/Rome" style="color:#84a6a4">http://en.wikipedia.org/wiki/Rome</a><br/>     <a href="http://dbpedia.org/resource/Rome" style="color:#84a6a4">http://dbpedia.org/resource/Rome</a><br/>     <a href="http://www.csc.org.il/db/browse.aspx?db=SB&a ...
# <tr><td><b>see also<p style="margin-top:5px; font-size:0.9em; font-weight:normal">Links are courtesy of <a href="https://www.trismegistos.org/dataservices/texrelations/documentation/">Trismegistos API</a></p></b></td><td><b>TM_ID</b>: <a href="http://www.trismegistos.org/text/265591">http://www.trismegistos.org/text/265591</a><br/>
# <b>EDCS</b>: <a href="http://db.edcs.eu/epigr/edcs_id_en.php?p_edcs_id=EDCS-08500005">http://db.edcs.eu/epigr/edcs_id_en.php?p_edcs_id=EDCS-08500005</a><br/>
# <b>EDR</b>: <a href="http://www.edr-edr.it/edr_programmi/res_complex_comune.php?do=book&amp;id_nr=EDR078758">http://www.edr-edr.it/edr_programmi/res_complex_comune.php?do=book&amp;id_nr=EDR078758</a><br/>
# </td></tr>
# <tr><td><b>Historic Period(s)</b></td><td><a href="http://n2t.net/ark:/99152/p0jrrjbchh2">Late Roman Republic (146 BC - 27 BC)</a>   (<a href="/inschrift/suche?hist_periode=per_3">show all inscriptions from this period</a>)<br/>
# <a href="http://n2t.net/ark:/99152/p0jrrjb66p3">Roman Republic (509 BC - 27 BC)</a>   (<a href="/inschrift/suche?hist_periode=per_2">show all inscriptions from this period</a>)<br/>
# </td></tr>
# <tr><td><b>work status</b></td><td>checked with photo<tr><td><b>last update</b></td><td>4 January 2010</td></tr>
# </td></tr>
# <tr><td><b>responsible individual</b></td><td><a href="/edh/bearbeiter/feraudi">Feraudi</a></td></tr>
#
# <div align="center"><table border="0"><tr><td align="center"><a href="#top">top</a></td></tr></table></div><div id="DialogLemma"></div>
# <script>
# $(document).ready(function() {
#     $("#DialogLemma").dialog({
#         autoOpen: false,
#         modal: true,
#         width:350,
#         resizable: true,
#         title: "Lemma Information"
#     });
#     $(".word").click(function(){
#         var hd = "HD000042";
#         var tid = document.getElementById(this.id).getAttribute("id");
#         var l = document.getElementById(this.id).getAttribute("lemma");
#         var pos = document.getElementById(this.id).getAttribute("pos");
#         $.ajax({
#                     url:"/cgi-bin/solrGetLemmaTranslation.pl",
#                     type:"get",
#                     data:{hd_nr: hd, token_id: tid},
#                     success: function(response){
#                         $("#DialogLemma").html(l + " (" + pos + ")<br /><br />" + response + "<p>Search all attestations of lemma <a href='/inschrift/suche?atext1_lem=" + l + "&lemmatize=false'>" + l + "</a></p>").dialog();
#                         $("#DialogLemma").dialog("open");
#                     }
#                 });
#     });
#
# });
# </script>
#
# <!-- eigentlicher Inhalt Ende -->
# <td id="inhaltRechts">
# <!-- Infobloecke Anfang -->
# <table class="infoBlockTabelle" style="margin-top:100px" width="100%">
# <tr>
# <td class="infoBlockLinks_Aktuell" style="height:100px"><p style="margin-left:26px;color:#C8656D;padding:1px;"><b>
# News:</b><p style="margin-left:26px;color:#323586;padding:1px;font-size:90%">– <a href="http://epigraphy.info/workshop_3_short_report.pdf" style="text-decoration:none;color:#323586" target="_blank">Report Workshop III</a><br> – <a href="https://doi.org/10.11588/heidok.00026599" style="text-decoration:none;color:#323586" target="_blank">Article EDH Data Reuse Options</a><br> – <a href="http://doi.org/10.11588/heidok.00026330" style="text-decoration:none;color:#323586" target="_blank">Report Workshop II</a><br> – <a href="https://www.hsozkult.de/webreview/id/rezwww-179" style="text-decoration:none;color:#323586" target="_blank">Review of EDH</a><br> – <a href="http://nbn-resolving.de/urn/resolver.pl?urn=urn:nbn:de:bsz:16-heidok-246746" style="text-decoration:none;color:#323586" target="_blank">Recommen-<br>dations<br>epigraphy.info</br></br></a><br> <br>– <a href="http://doi.org/10.11588/heidok.00024397" style="text-decoration:none;color:#323586" target="_blank">Report<br>Workshop I</br></a><br> <br>– <a href="http://www.currentepigraphy.org/2018/03/16/epigraphy-info-workshop/" style="text-decoration:none;color:#323586" target="_blank">Workshop I epigraphy.info</a><br> <br>– <a href="http://nbn-resolving.de/urn/resolver.pl?urn=urn:nbn:de:bsz:16-heidok-221411" style="text-decoration:none;color:#323586" target="_blank">Article<br/>epigraphy.info</a> </br></br></br></br></br></br></br></br></br></br></p>
# </p></td>
# </tr>
# <tr><td style="padding:0px;height:21px;background-image:url(/images/seitenleiste_rechts_schatten.png)"> </td></tr>
# </table>
# <!-- Infobloecke Ende -->
# </td>
#
# <!-- Inhalt Ende -->
# <!-- Fuss Anfang -->
# <tr id="fussHoehe">
# <td colspan="3" id="fuss">
# <table id="fussTabelle" width="100%">
# <tr>
# <td><a class="fussLinks" href="#" onclick="showDialog('/tplInhalt/zitierweise_en.html','Canonical URI','500px'); return false;">Canonical URI</a></td><td><a class="fussLinks" href="http://www.hadw-bw.de/datenschutzerklaerung">Copyright, disclaimer, data privacy statement</a></td><td><a class="fussLinks" href="#" onclick="showDialog('/tplInhalt/anregungen_en.html','Suggestions / Questions / Problems','500px'); return false;">Suggestions / Questions / Problems</a></td><td><a class="fussLinks" href="#" onclick="showDialog('/tplInhalt/impressum_en.html','Imprint','500px'); return false;">Imprint</a></td> </tr>
# </table>
# </td>
# </tr>
#
# <!-- Fuss Ende -->
# <script src="/jq/tg.js" type="text/javascript"></script><!-- TypeGreek by Randy Hoyt (TypeGreek.com) -->
# <script src="https://cdnjs.cloudflare.com/ajax/libs/clipboard.js/1.4.0/clipboard.min.js" type="text/javascript"></script>
# <script src="/jq/jquery.tree.js" type="text/javascript"></script>
# <script src="/jq/jQuery-collapsiblePanel.js" type="text/javascript"></script>
# <script src="/jq/jquery-ui-slider-pips.min.js" type="text/javascript"></script>
# <script src="/js/edh.js" type="text/javascript"></script>
#
#
#
# --------------------------------------end------------------------------------
# Latin
