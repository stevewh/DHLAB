# %% [markdown]
# # ECC058 - DHLab
#
# # Working with Data
#
#
# #### Prof. Stephen White
# #### stephen.white@unive.it

# %%
import pandas as pd
import numpy as np

# %%
#load your worksheet
#epixls = pd.ExcelFile('Epi Data Collection Sample.xlsx')
#epixls = pd.ExcelFile('../Elisa/elisabrunetta_data_collection.xlsx')
#epixls = pd.ExcelFile('../DH5 Marco/EDH Epigrafia.xlsx')
epixls = pd.ExcelFile('../Linda/FINAL_Linda_correct_Epi Data Collection Sample.xlsx')
#epixls = pd.ExcelFile('../Serena/guida_epidata_collection.xlsx')

print("variable epixls has type ",type(epixls))
#df_epi = pd.read_excel(epixls,header=None)
#df_epi = pd.read_excel(epixls,sheet_name='EDH',header=None)
df_epi = pd.read_excel(epixls,sheet_name=['EDR','EDH'],header=None)
print("variable df_epi has type ",type(df_epi))
df_epi
# Out:
# variable epixls has type  <class 'pandas.io.excel.ExcelFile'>
# variable df_epi has type  <class 'collections.OrderedDict'>
# OrderedDict([('EDR',
#                                  0                                                  1  \
#               0            Ref URL  http://www.edr-edr.it/edr_programmi/res_comple...
#               1                 ID                                          EDR000113
#               2           Alt IDs?                                           TM258845
#               3       Object Type?                                            tabula
#               4           Material                                            marmor
#               5           Language                                            latina
#               6               Date                            - 1 571 d.C. / 573 d.C.
#               7   Inscription Type                                       sepulcralis
# ...

# %%
df_epi
# Out:
# OrderedDict([('EDR',
#                                  0                                                  1  \
#               0            Ref URL  http://www.edr-edr.it/edr_programmi/res_comple...
#               1                 ID                                          EDR000113
#               2           Alt IDs?                                           TM258845
#               3       Object Type?                                            tabula
#               4           Material                                            marmor
#               5           Language                                            latina
#               6               Date                            - 1 571 d.C. / 573 d.C.
#               7   Inscription Type                                       sepulcralis
#               8        Image  URLs  http://www.edr-edr.it//foto_epigrafi/immagini_...
#               9                NaN                                                NaN
# ...

# %%
df_epi.index
# Out:
# RangeIndex(start=0, stop=25, step=1)

# %%
#df_epi = pd.read_excel(xls,sheet_name='EDR',header=None)
#df_epi = pd.read_excel(xls,sheet_name=['EDR','EDH'],header=None)
df_epi = pd.read_excel(xls,sheet_name=None,header=None)
df_epi
# note how pandas uses first row as headers
# Out:
# OrderedDict([('EDR',
#                                  0                                                  1  \
#               0            Ref URL  http://www.edr-edr.it/edr_programmi/res_comple...
#               1                 ID                                          EDR000113
#               2           Alt IDs?                                           TM258845
#               3       Object Type?                                            tabula
#               4           Material                                            marmor
#               5           Language                                            latina
#               6               Date                            - 1 571 d.C. / 573 d.C.
#               7   Inscription Type                                       sepulcralis
#               8        Image  URLs  http://www.edr-edr.it//foto_epigrafi/immagini_...
#               9                NaN                                                NaN
# ...

# %%
df_epi['EDR (2)'].iloc[9,1].split('\n')
# Out:
# ['Hic requiesci[t in pa]=',
#  'ce b(onae) m(emoriae) Donatus [diaco]=',
#  'nus, qui vixit in h[oc sae]=',
#  '[cl(o) an]nos p(lus) m(inus) XL, d[ep(ositus) est]',
#  '[sub (die) - men(se) Ianua]ṛịọ ',
#  '[Imp(eratore) D(omino) N(ostro) Iustino] p̣(er)p(etuo) Aug(usto)',
#  '[anno] VI.']
